# %%
from dataset import *
from train import *

# %%
seed_all(SEED)
if MODE == "prepare":
    prepare_dataset()
elif MODE == "train":
    train()
# Out:
# actor params: 2,035,716
# critic params: 2,282,440
# ep 0:   0%|          | 0/86400 [00:00<?, ?it/s]
# episode 0 steps=16476 reward=-33.4370 bal=66.56 critic=0.0000 actor=0.0000 ent=0.0000 alpha=0.0000
# ep 1:   0%|          | 0/86400 [00:00<?, ?it/s]
